# %% [markdown]
# # Environment & Config Check

# %%
from dotenv import load_dotenv
import os
import numpy as np

load_dotenv()
print("API_KEY present:", os.getenv("API_KEY") is not None)

arr = np.array([1, 2, 3])
print("NumPy check:", arr * 2)
# Out:
# API_KEY present: True
# NumPy check: [2 4 6]
